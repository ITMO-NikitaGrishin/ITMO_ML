# %% [markdown]
# # Лабораторная работа №1

# %% [markdown]
# ## 1.1 Вероятностное пространство. Формула Байеса

# %% [markdown]
# Определение
#
# События
# A и
# B называются ***независимыми***, если выполняется равенство
#
# 𝑃 ( 𝐴 ∩ 𝐵 ) = 𝑃(𝐴) ⋅ 𝑃(𝐵).
#
# Если это равенство не выполняется, то события зависимы.

# %% [markdown]
# ## Задание 1

# %% [markdown]
# ### а) Несовместные события

# %% [markdown]
# если A и B - несовместные события, тогда
#
# ####  𝐴 ∩ 𝐵 = ∅
#
# и
#
# #### 𝑃 ( 𝐴 ∩ 𝐵 ) = 0
#
# Если при этом 𝑃(𝐴) > 0 и 𝑃(𝐵) > 0, тогда
#
# #### 𝑃(𝐴) ⋅ 𝑃(𝐵) > 0
#
# Следовательно
#
# #### 𝑃 ( 𝐴 ∩ 𝐵 ) != 𝑃(𝐴) ⋅ 𝑃(𝐵)
#
# В таком случае несовместные события ***зависимые***

# %% [markdown]
# Однако, возможно и исключение, при условии, что 𝑃(𝐴) = 0 или 𝑃(𝐵) = 0
#
# В таком случае события будут ***независимые***

# %% [markdown]
# ### б) События образующие σ-алгебру Σ в (Ω,Σ,𝑃)

# %% [markdown]
# Пусть Ω = {1,2} ,тогда
#
# #### Σ={∅,{1},{2},Ω}
#
# #### P({1}) = P({2}) = 1/2	​
#
# Возьмём A = {1}, B={2}, тогда
#
# #### P(A) = P(B) = 1/2
#
# #### P(A) ⋅ P(B) = 1/4​
#
# #### P( A ∩ B ) = P(∅) = 0 != 1/4
#
# Следовательно события A и B - ***зависимые***

# %% [markdown]
# Исключение , если Σ={∅,Ω} , тогда все события имеют вероятность 0 или 1 и тогда события будут ***независимые***

# %% [markdown]
# ### с) События с одинаковой вероятностью

# %% [markdown]
# Тут могут быть как зависимые так и нет , смотря пересекаются у нас события или нет

# %% [markdown]
# Пример 1

# %% [markdown]
# Пусть Ω = {1,2,3,4}, равновероятно
#
# A = {1,2},  B = {3,4}, тогда
#
# #### P(A) = P(B) = 1/2
#
# #### P( A ∩ B ) = P(∅) = 0 != 1/4
#
# В таком случае события - ***зависимые***

# %% [markdown]
# Пример 2

# %% [markdown]
# Пусть Ω = {1,2,3,4}, равновероятно
#
# A = {1,2},  B = {1,3}, тогда
#
# #### P(A) = P(B) = 1/2
#
# #### P({1})	= 1/4
#
# #### P( A ∩ B ) = P({1}) = 1/4 = 1/2 ⋅ 1/2
#
# В таком случае события - ***независимые***

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Обозначим исходы двух подбрасываний как (x,y), где x — результат первой монеты, y — результат второй\
# Г — герб,\
# Р — решка
#
# Ω = {(Г,Г),(Г,Р),(Р,Г),(Р,Р)}
#
# События:
#
# A = {(Г,Г),(Г,Р)}\
# B = {(Р,Г),(Р,Р)}\
# C = {(Г,Г),(Р,Г)}\
# D = {(Г,Р),(Р,Р)}\
# E = {(Г,Г),(Г,Р),(Р,Г)}\
# F = {(Г,Р),(Р,Г),(Р,Р)}\
# G = {(Г,Р),(Р,Г)}\
# H = {(Р,Р)}\
# K = {(Г,Г)}​

# %% [markdown]
# Решение:

# %% [markdown]
# A + C = E\
# AC = K\
# EF = G\
# G + E = E\
# GE = G\
# BD = H\
# E + K =E

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Весь круг - 360°
#
# 2 закрашенные области по 20°
#
# 20 + 20 = 40°
#
# Следовательно вероятность :
#
# #### P = 40/360 = 0.11 = 11%

# %% [markdown]
# ## Задание 4

# %% [markdown]
# ## Задание 5

# %% [markdown]
# Самолёт поражён, если выполнено одно из трёх условий:
#
# - X1 ≥ 1 (одно попадание в первую часть), или
#
# - X2 ≥ 2 (две и более попаданий во вторую), или
#
# - X3 ≥ 3 (три и более попаданий в третью)

# %% [markdown]
# #### m=1
#
# При одном снаряде возможно только одно попадание, поэтому поражение возможно только если он попал в первую часть:
#
# **P(A ∣ 1) = P(X1 = 1) = p1**

# %% [markdown]
# #### m=2
#
# При двух снарядах поражение произойдёт, если X1 ≥ 1 или X2 = 2
#
# Проще найти события, при которых нет поражения. Это когда в первую часть не попали и во вторую попало не более одного снаряда (т. е. фактически либо оба в третью, либо один во вторую и один в третью)
#
# Соответствующие вероятности:
#
# - X1 = 0, X2 = 0,X3 = 2 с вероятностью $𝑝3^2$
#
# - X1 = 0,X2 = 1,X3 = 1 с вероятностью $2𝑝2𝑝3$
#
#
# Значит
#
# **P(A ∣ 2) = 1 − ($𝑝3^2$ + $2𝑝2𝑝3$) = 1 - p3(p3+2p2)**

# %% [markdown]
# #### m=3
#
# При трёх снарядах поражение наступает, если X1 ≥ 1 или X2 ≥ 2 или X3 ≥ 3
#
# Найдём единственный исход, при котором поражения нет. Единственная комбинация, удовлетворяющая этому, это (X1,X2,X3) = (0,1,2)
#
# Её вероятность равна $3p2p3^2$
#
# Следовательно
#
# **P(A ∣ 3) = 1 - $3p2p3^2$**

# %% [markdown]
# #### m=4
#
# При четырёх снарядах любая возможная композиция попаданий даёт поражение
#
# **P(A ∣ 4) = 1**

# %% [markdown]
# ## 1.2 Случайный вектор и числовые характеристики

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Функция
#
# $$
# f_{\xi}(x, y) = \frac{e^{-2|y|}}{\pi(1 + x^2)}, \quad (x, y) \in \mathbb{R}^2
# $$
#
# неотрицательна и интегрируема
#
# $$
# \iint_{\mathbb{R}^2} f_{\xi}(x, y) \, dx \, dy
# = \int_{-\infty}^{\infty} \frac{dx}{\pi(1 + x^2)} \cdot
# \int_{-\infty}^{\infty} e^{-2|y|} \, dy.
# $$
#
# Известно, что
#
# $$
# \int_{-\infty}^{\infty} \frac{dx}{\pi(1 + x^2)} = 1
# \quad ,
# $$
#
# и
#
# $$
# \int_{-\infty}^{\infty} e^{-2|y|} \, dy
# = 2 \int_{0}^{\infty} e^{-2y} \, dy
# = 2 \cdot \frac{1}{2} = 1.
# $$
#
# Следовательно, полная интегральная масса равна 1
#
# Значит, функция является **плотностью распределения случайного вектора**

# %% [markdown]
# ## Задание 2
